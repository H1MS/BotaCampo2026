# %%
print("hola mundo")
# Out:
# hola mundo

# %%
#Primer Challenge
nombre = 'Carlo Limiti'
edad = 27
ciudad = 'Asuncion'
print(f'Mi nombre es {nombre}\ny tengo {edad}')
# Out:
# Mi nombre es Carlo Limiti
# y tengo 27

# %%
#Segundo Challenge
cantidad_de_manzanas = 312
cantidad_de_naranjas = 176
cantidad_de_frutas = cantidad_de_naranjas + cantidad_de_manzanas
print(f'Empezaste el dia con {cantidad_de_frutas} frutas')

frutas_vendidas = 453
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print(f'Vendiste {frutas_vendidas}, te quedan {frutas_restantes} por vender')
# Out:
# Empezaste el dia con 488 frutas
# Vendiste 453, te quedan 35 por vender

# %%
#Tercer Challenge
nombre = 'Manuel'
apellido = 'Ayala'
nombre_comp = nombre+ ' ' +apellido
print(f'Buenas tardes. \nMi nombre es {nombre_comp}, mucho gusto.')
# Out:
# Buenas tardes.
# Mi nombre es Manuel Ayala, mucho gusto.

# %%
#Cuarto Challenge
distancia_1 = input('Distancia al parque en km')
distancia_2 = input('Recorrido dentro del parque km')
distancia_1_km = float(distancia_1)
distancia_2_km = float(distancia_2)
distancia_total = distancia_1_km *2 + distancia_2_km 
print(f'Te falta caminar {distancia_total} km')
# Out:
# Te falta caminar 11.0 km

# %%
#Quinto Challenge
#Convertir Dolares a Guaranies(con vuelto)

def una_tarde_en_lol():
    print('Buscar partida') 
    print('Encontrar partida')  
    print('Entrar a partida')
    print('Tiltearme')
    print('Victoria en rojo\n')

una_tarde_en_lol()
una_tarde_en_lol()
una_tarde_en_lol()
# Out:
# Buscar a partida
# Encontrar partida
# Entrar a partida
# Tiltearme
# Victoria en rojo
# Buscar a partida
# Encontrar partida
# Entrar a partida
# Tiltearme
# Victoria en rojo
# Buscar a partida
# Encontrar partida
# Entrar a partida
# Tiltearme
# Victoria en rojo

# %%
#Sexto Challenge
#Rehacer, Crear ua funcion que me pida variables (Variable locales)
# Out:
# Busca un toyota rathis del 90009, ese modelo lo tenemos por 27millones, usado

# %%
#Septimo Challenge
#Rechacer, una funcion (para comprar un producto) que use variables locales y globales, he imprima las caracteristicas del mismo
#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 15
#      12     almacenamiento = spec4
#      13     print(f'Busca una {producto}, con un procesador {cpu}, de {ram}gb de memoria RAM, con {almacenamiento}gb y una {gpu}')
# ---> 15 pc_part_picker()
#
# TypeError: pc_part_picker() missing 4 required positional arguments: 'cpu', 'ram', 'gpu', and 'almacenamiento'
